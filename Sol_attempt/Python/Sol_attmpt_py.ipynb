# %%
import sympy as sp
from IPython.display import display, Math

# render sympy output as LaTeX/MathJax in the notebook
sp.init_printing()


def show(label, expr):
    """pprint replacement: render `expr` as LaTeX with a text label."""
    display(Math(r"\text{%s:}\quad %s" % (label, sp.latex(expr))))

# %%
# --- symbols and functions ---
r = sp.symbols('r', positive=True)
rs, L, E = sp.symbols('r_s L E', positive=True)
t = sp.symbols('t')

m = sp.Function('m')(r)
rdot = sp.Function('rdot')(r)   # \dot r as a function of r
rddot = sp.Function('rddot')(r) # \ddot r as a function of r

# %%
# --- pieces of the equation ---
P = 1 - rs/r - rdot
A = rddot + rs/(2*(r - rs)*r) * rdot**2
B = (1 - rs/r) * (L**2/r**3 - rs*E**2/(2*r**2))

# %%
# --- original ODE ---
ode = sp.Eq(sp.diff(m, r) * P, m*A + B/m)
show("Original ODE", ode)
# Out:
# $\displaystyle \text{Original ODE:}\quad \left(- \dot{r}{\left(r \right)} + 1 - \frac{r_{s}}{r}\right) \frac{d}{d r} m{\left(r \right)} = \frac{\left(1 - \frac{r_{s}}{r}\right) \left(- \frac{E^{2} r_{s}}{2 r^{2}} + \frac{L^{2}}{r^{3}}\right)}{m{\left(r \right)}} + \left(\ddot{r}{\left(r \right)} + \frac{r_{s} \dot{r}^{2}{\left(r \right)}}{r \left(2 r - 2 r_{s}\right)}\right) m{\left(r \right)}$

# %%
# --- attempt 1: direct dsolve (may recognize Bernoulli form) ---
try:
    sol_direct = sp.dsolve(ode, m, hint='Bernoulli', simplify=False)
    show("Direct solution", sol_direct)
except NotImplementedError:
    print("\nDirect dsolve failed — falling back to u = m^2 substitution.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 # --- attempt 1: direct dsolve (may recognize Bernoulli form) ---
#       2 try:
#       3     sol_direct = sp.dsolve(ode, m, hint='Bernoulli', simplify=False)
#       4     show("Direct solution", sol_direct)
# ----> 5 except NotImplementedError:
#       6     print("\nDirect dsolve failed — falling back to u = m^2 substitution.")
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\solvers\ode\ode.py:640, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     637 else:
#     638     # The key 'hint' stores the hint needed to be solved for.
#     639     hint = hints['hint']
# --> 640     return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\solvers\ode\ode.py:689, in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     687     exprs = solvefunc(eq, func, order, match)
#     688 if isinstance(exprs, list):
# --> 689     rv = [_handle_Integral(expr, func, hint) for expr in exprs]
#     690 else:
#     691     rv = _handle_Integral(exprs, func, hint)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\solvers\ode\ode.py:2187, in _handle_Integral(expr, func, hint)
#    2185     sol = expr
#    2186 elif not hint.endswith("_Integral"):
# -> 2187     sol = expr.doit()
#    2188 else:
#    2189     sol = expr
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\basic.py:1947, in Basic.doit(self, **hints)
#    1928 """Evaluate objects that are not evaluated by default like limits,
#    1929 integrals, sums and products. All objects of this kind will be
#    1930 evaluated recursively, unless some species were excluded via 'hints'
#    (...)   1944
#    1945 """
#    1946 if hints.get('deep', True):
# -> 1947     terms = [term.doit(**hints) if isinstance(term, Basic) else term
#    1948                                  for term in self.args]
#    1949     return self.func(*terms)
#    1950 else:
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\operations.py:478, in AssocOp.doit(self, **hints)
#     476 def doit(self, **hints):
#     477     if hints.get('deep', True):
# --> 478         terms = [term.doit(**hints) for term in self.args]
#     479     else:
#     480         terms = self.args
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\operations.py:478, in AssocOp.doit(self, **hints)
#     476 def doit(self, **hints):
#     477     if hints.get('deep', True):
# --> 478         terms = [term.doit(**hints) for term in self.args]
#     479     else:
#     480         terms = self.args
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\operations.py:478, in AssocOp.doit(self, **hints)
#     476 def doit(self, **hints):
#     477     if hints.get('deep', True):
# --> 478         terms = [term.doit(**hints) for term in self.args]
#     479     else:
#     480         terms = self.args
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\integrals\integrals.py:619, in Integral.doit(self, **hints)
#     617     antideriv = None
#     618 else:
# --> 619     antideriv = self._eval_integral(
#     620         function, xab[0], **eval_kwargs)
#     621     if antideriv is None and meijerg is True:
#     622         ret = try_meijerg(function, xab)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\integrals\integrals.py:1091, in Integral._eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1089 try:
#    1090     if conds == 'piecewise':
# -> 1091         h = heurisch_wrapper(g, x, hints=[])
#    1092     else:
#    1093         h = heurisch_(g, x, hints=[])
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\integrals\heurisch.py:144, in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     141 if not f.has_free(x):
#     142     return f*x
# --> 144 res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
#     145                unnecessary_permutations, _try_heurisch)
#     146 if not isinstance(res, Basic):
#     147     return res
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\integrals\heurisch.py:764, in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     762         solution = _integrate()
#     763 else:
# --> 764     solution = _integrate()
#     766 if solution is not None:
#     767     antideriv = solution.subs(rev_mapping)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\integrals\heurisch.py:706, in heurisch.<locals>._integrate(field)
#     700 # TODO: Currently it's better to use symbolic expressions here instead
#     701 # of rational functions, because it's simpler and FracElement doesn't
#     702 # give big speed improvement yet. This is because cancellation is slow
#     703 # due to slow polynomial GCD algorithms. If this gets improved then
#     704 # revise this code.
#     705 candidate = poly_part/poly_denom + Add(*log_part) + Add(*atan_part)
# --> 706 h = F - _derivation(candidate) / denom
#     707 raw_numer = h.as_numer_denom()[0]
#     709 # Rewrite raw_numer as a polynomial in K[coeffs][V] where K is a field
#     710 # that we have to determine. We can't use simply atoms() because log(3),
#     711 # sqrt(y) and similar expressions can appear, leading to non-trivial
#     712 # domains.
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\integrals\heurisch.py:543, in heurisch.<locals>._derivation(h)
#     542 def _derivation(h):
# --> 543     return Add(*[ d * h.diff(v) for d, v in zip(numers, V) ])
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1466, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     if not old_v.is_scalar and not hasattr(
#    1460             old_v, '_eval_derivative'):
#    1461         # special hack providing evaluation for classes
#    1462         # that have defined is_scalar=True but have no
#    1463         # _eval_derivative defined
#    1464         expr *= old_v.diff(old_v)
# -> 1466 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1467 if obj is not None and obj.is_zero:
#    1468     return obj
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1927, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1921 @classmethod
#    1922 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1923     # Evaluate the derivative `n` times.  If
#    1924     # `_eval_derivative_n_times` is not overridden by the current
#    1925     # object, the default in `Basic` will call a loop over
#    1926     # `_eval_derivative`:
# -> 1927     return expr._eval_derivative_n_times(v, count)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\basic.py:1975, in Basic._eval_derivative_n_times(self, s, n)
#    1973 for i in range(n):
#    1974     prev = obj
# -> 1975     obj = obj._eval_derivative(s)
#    1976     if obj is None:
#    1977         return None
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\add.py:504, in Add._eval_derivative(self, s)
#     502 @cacheit
#     503 def _eval_derivative(self, s):
# --> 504     return self.func(*[a.diff(s) for a in self.args])
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1466, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     if not old_v.is_scalar and not hasattr(
#    1460             old_v, '_eval_derivative'):
#    1461         # special hack providing evaluation for classes
#    1462         # that have defined is_scalar=True but have no
#    1463         # _eval_derivative defined
#    1464         expr *= old_v.diff(old_v)
# -> 1466 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1467 if obj is not None and obj.is_zero:
#    1468     return obj
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1927, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1921 @classmethod
#    1922 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1923     # Evaluate the derivative `n` times.  If
#    1924     # `_eval_derivative_n_times` is not overridden by the current
#    1925     # object, the default in `Basic` will call a loop over
#    1926     # `_eval_derivative`:
# -> 1927     return expr._eval_derivative_n_times(v, count)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\mul.py:1005, in Mul._eval_derivative_n_times(self, s, n)
#    1003 from sympy.ntheory.multinomial import multinomial_coefficients_iterator
#    1004 for kvals, c in multinomial_coefficients_iterator(m, n):
# -> 1005     p = Mul(*[arg.diff((s, k)) for k, arg in zip(kvals, args)])
#    1006     terms.append(c * p)
#    1007 return Add(*terms)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1466, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     if not old_v.is_scalar and not hasattr(
#    1460             old_v, '_eval_derivative'):
#    1461         # special hack providing evaluation for classes
#    1462         # that have defined is_scalar=True but have no
#    1463         # _eval_derivative defined
#    1464         expr *= old_v.diff(old_v)
# -> 1466 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1467 if obj is not None and obj.is_zero:
#    1468     return obj
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1927, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1921 @classmethod
#    1922 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1923     # Evaluate the derivative `n` times.  If
#    1924     # `_eval_derivative_n_times` is not overridden by the current
#    1925     # object, the default in `Basic` will call a loop over
#    1926     # `_eval_derivative`:
# -> 1927     return expr._eval_derivative_n_times(v, count)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\basic.py:1975, in Basic._eval_derivative_n_times(self, s, n)
#    1973 for i in range(n):
#    1974     prev = obj
# -> 1975     obj = obj._eval_derivative(s)
#    1976     if obj is None:
#    1977         return None
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\add.py:504, in Add._eval_derivative(self, s)
#     502 @cacheit
#     503 def _eval_derivative(self, s):
# --> 504     return self.func(*[a.diff(s) for a in self.args])
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1466, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     if not old_v.is_scalar and not hasattr(
#    1460             old_v, '_eval_derivative'):
#    1461         # special hack providing evaluation for classes
#    1462         # that have defined is_scalar=True but have no
#    1463         # _eval_derivative defined
#    1464         expr *= old_v.diff(old_v)
# -> 1466 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1467 if obj is not None and obj.is_zero:
#    1468     return obj
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\function.py:1927, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1921 @classmethod
#    1922 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1923     # Evaluate the derivative `n` times.  If
#    1924     # `_eval_derivative_n_times` is not overridden by the current
#    1925     # object, the default in `Basic` will call a loop over
#    1926     # `_eval_derivative`:
# -> 1927     return expr._eval_derivative_n_times(v, count)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\mul.py:1005, in Mul._eval_derivative_n_times(self, s, n)
#    1003 from sympy.ntheory.multinomial import multinomial_coefficients_iterator
#    1004 for kvals, c in multinomial_coefficients_iterator(m, n):
# -> 1005     p = Mul(*[arg.diff((s, k)) for k, arg in zip(kvals, args)])
#    1006     terms.append(c * p)
#    1007 return Add(*terms)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\operations.py:108, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#     105 if len(args) == 1:
#     106     return args[0]
# --> 108 c_part, nc_part, order_symbols = cls.flatten(args)
#     109 is_commutative = not nc_part
#     110 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\mul.py:722, in Mul.flatten(cls, seq)
#     719 c_part = _new
#     721 # order commutative part canonically
# --> 722 _mulsort(c_part)
#     724 # current code expects coeff to be always in slot-0
#     725 if coeff is not S.One:
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\mul.py:36, in _mulsort(args)
#      34 def _mulsort(args):
#      35     # in-place sorting of args
# ---> 36     args.sort(key=_args_sortkey)
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\basic.py:400, in Basic.compare(self, other)
#     398 n1 = self.__class__
#     399 n2 = other.__class__
# --> 400 c = _cmp_name(n1, n2)
#     401 if c:
#     402     return c
#
# File c:\Users\Jonah\.conda\envs\Phys\Lib\site-packages\sympy\core\basic.py:117, in _cmp_name(x, y)
#     114     return 0
#     116 # If the other object is not a Basic subclass, then we are not equal to it.
# --> 117 if not issubclass(y, Basic):
#     118     return -1
#     120 UNKNOWN = len(ordering_of_classes) + 1
#
# KeyboardInterrupt:

# %%
# --- attempt 2: linearize via u = m^2 ---
u = sp.Function('u')(r)
ode_u = sp.Eq(sp.diff(u, r) - (2*A/P)*u, 2*B/P)
show("Linearized ODE in u = m^2", ode_u)

sol_u = sp.dsolve(ode_u, u)
show("Solution for u(r)", sol_u)

m_sol = sp.sqrt(sol_u.rhs)
show("Recovered m(r) = sqrt(u(r))", m_sol)
